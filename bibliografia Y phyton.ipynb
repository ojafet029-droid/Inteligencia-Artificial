# %% [markdown]
# # `MI BIBLIOGRAFIA`

# %% [markdown]
#   <a href="https://github.com/DenverCoder1/readme-typing-svg"><img src="https://readme-typing-svg.herokuapp.com?font=Time+New+Roman&color=cyan&size=25&center=true&vCenter=true&width=600&height=100&lines=Intentando+ser+Ingeniero+en+Computación+..&hearts;++;Aprendiendo+ a+programar+Python;Me+gusta+la+Inteligencia+Artificial."></a>
# </p>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. ### 😄<span style="color:purple;">  Nací en el año de 2005 en la Ciudad de Toluca, México mis padres son Edith Guadalupe García y Jeohvany Cruz Reyes mi nacimiento fue incrible ya que era el unico niño dentro de las 2 familias tanto paterna como materna, vivo desde ese momento en el pueblo de Tlachaloya 1era Sección mi trayecto durante mi crecimiento fue muy agradable ya que mi infancia fue muy linda aunque tuve algunas caidas no me suena mal </span>
#
# - ### 😌 <span style="color:yellow;">  ingrese al **kinder** `Reinaldo Escobar Castañeda` a la edad de 3 años como oyente con la Maestra  ~~Marlen~~   vivi ese año muy bien mas adelante cruce el 2 año de kiner con la profesora Rita me fue muy bien igual aunque era muy desatroso y me amarraron a una silla en un momento de mi curso del 2 año al 3er semestre cuerse el final de año con la maestra Yes fue el mejor año de mi trayecto por el kiner ya que era muy linda con nosotro y mas adelante nos fuimos  a la **Primaria** `Prof. Francisco Estrada` </span>
#
# 2.  ### 😜 a la  <span style="color:pink;"> edad de los 6 años mi trayecto durante la primaria fue muy padre pero fue tambien muy agradable vivi muchas experiencias con antiguos compañeros de la infancia curse el primer año con la Profesora     ~~Veronica~~      fue agrdable ese año aunque no recuerdo muy bien lo que vivi con ella, mas adelante curse el 2 y 3 año lo curse con la Profesora ~~Remedios~~ hay si vivi muchos recuerdos con ellos una de las mas emocionantes fue falcificar una firma que no me agrado haberlo realizado mas adelante curse el 4 año con otra profesora Joselin en ese año la verdad no tuve muchas experiencias ya que la profesora no pudo estar debido a que tuvo su enmbarazo y nos dejo a la mitad de año </span>
#
# - ### 😛 <span style="color:green;"> y mas adelante curse el 5semestre con la profesora     ~~Julieta~~     a la cual haciamios enojar a diario incluso un dia se desmayo de lo enojada que estaba pero finalmente nos  fuimos al 6to semestre y concluimos la primaria con gran orgullo y en ese trayecto vivi muy bien con mi familia mis padres me apoyaban mucho con todas mis tareas y todo lo que ocupaba no me dejaban hacian todo lo posible por conseguir lo que ocupara aunque en este momento no me siento muy bien por que flojeaba mucho y no aproveche lo que me proporcionaron en ese momento, despues mas adelante dimos un salto a la **Secundaria** en Toluca con el nombre de `Anexa a la Normal n.1 de Toluca` en ese momento de mi trayectoria </span>
#
# - ###  😬 <span style="color:red;">de mi vida la pase increible ya que hay encontre a mis mejores amigos hasta el momento hay curse 3 años fantasticos en donde pase grandes momentos hay aprendi mucho a echarle muchas ganas y saber que habia aprovechado muy bien lo que me proporcionaron mis padres hasta logre sacar reconocimiento en ese momento y pude haber estado en la escolta pero no me sabia mi promedio jajaj pero si pude aun que al tratar de finalizar la secundaria ocurrio la ~~PANDEMIA~~ lo cual nos distancio y tuvimos que terminar el curso en linea y sin ninguna despedida pero logramos guardar una gran hermandad y mas adelante me fui para la prepa 2 hay es donde comenze y me   relacione muy bien con mis compañeros aunque no lleve grandes semestres ya que todo fue en linea pero logre cursas los 6 semestres de prepa en donde tuve altas y bajas, realice grandes practicas de conocimiento con mis compañeros, ademas tambien convivi con mi familia y tuve grandes festejos ya que tambien aprendi muy bien con mis profes de la prepa y culmine mi prepa </span>

# %% [markdown]
# | 1. FAMILIA PATERNA 👪 |

# %% [markdown]
# |- ABUE P: WILFRIDO|
# |------------------|
# |- ABUE M: OFELIA|
# 11. HIJOS DE ABUELOS P: 👫
#
# |- WILFRIDO CRUZ REYES|
# |---------------------|
# |- JEHOVANY CRUZ REYES|
# |- PATRICIA CRUZ REYES|

# %% [markdown]
# 2. FAMILIA MATERNA: 👪

# %% [markdown]
# |- ABUE M: OFELIA ROJAS|
# |----------------------|
# |- ABUE M: WILFRIDO FLORES|

# %% [markdown]
# 21. HIJOS DE ABUELOS M: 👫

# %% [markdown]
# |- EMMANUEL ROSALES|
# |------------------|
# |- ANALILIA ROSALES|
# |- MIRIAM ROSALES|
# |- EDITH ROSALES|

# %% [markdown]
#    3. MIS GUSTOS DE FUTBOOL ⚽

# %% [markdown]
# <https://www.youtube.com/watch?v=fYzWWsM9Ljc&pp=ygURdmlkZW8gZGVsIGFtZXJpY2HSBwkJsgkBhyohjO8%3D>

# %% [markdown]
# ![Texto alternativo](https://imgs.search.brave.com/WepMWyG3vAKW5QlP6mH6uX7oRqnN4CIdBOH_MfuSAOs/rs:fit:860:0:0:0/g:ce/aHR0cHM6Ly9pLnBp/bmltZy5jb20vb3Jp/Z2luYWxzLzg4LzQw/LzkyLzg4NDA5MjU4/MGE0M2I4ZTdkZDg2/MDNhN2U4YmM5M2Fl/LmpwZw)

# %% [markdown]
# ![textoalternativo](https://imgs.search.brave.com/aBav-A8gl2UAjGevom8BqsLwgMD7fueleR2mxHGHSKk/rs:fit:500:0:1:0/g:)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# | Escuela | Tacos | Ingeneria |
# |--------------|--------------|--------------|
# | Dato 1 | Dato 2 | Dato 3 |
# | Dato 4 | Dato 5 | Dato 6 |

# %% [markdown]
# La fórmula de la recta es $y = mx + b$

# %% [markdown]
# $\sum_{i=1}^n i^2$
# $\int_0^\infty e^{-x}\,dx$

# %% [markdown]
# $$
# \begin{bmatrix}
# 1 & 0 \\
# 0 & 1
# \end{bmatrix}
# $$

# %% [markdown]
# ---

# %% [markdown]
# ### 1-. Uso se librerias phyton

# %% [markdown]
# ##### EJEMPLO

# %%
import math
import random

from datetime import date

raiz_IA = math.sqrt(144)
print("Raíz de IA:", raiz_IA)
# Out:
# Raíz de IA: 12.0
# Raíz de IA: 12.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <span style="color:yellow;">  En esta parte utilizamos 2 librerias las cuales nos ayudaron a poder ingresar datos como numeros y nos permitio la otra librerias poder realizar operaciones matematicas en este caso Raiz Cuadrada de un numero y poder imprimir el resultado de la operación despues de ejecutar el codigo</span>

# %% [markdown]
# <span style="color:green;">sbsjbsj</span>

# %% [markdown]
# ---

# %% [markdown]
# ### 2-. Variables y Tipos de Datos

# %% [markdown]
# ##### EJEMPLO

# %%
edad = 25               # int
altura_m = 1.85         # float
estudiante = False       # bool

print(edad, type(edad))
print(altura_m, type(altura_m))
print(estudiante, type(estudiante))
# Out:
# 25 <class 'int'>
# 1.85 <class 'float'>
# False <class 'bool'>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <span style="color:pink;">En este espacio de variables estamos declarando variables de cualquier tipo y lo que hace este pequeño codigo es advinar con la ayuda de las libererias el tipo de variable que estamos declarando</span>

# %% [markdown]
# ---

# %% [markdown]
# ###  3-. Entrada/Salida y Conversiones

# %% [markdown]
# ##### EJEMPLO

# %%
a_texto = "10"
b_texto = "7"

a = float(a_texto)  
b = int(b_texto)    

resta = a - b
division = a / b

print(f"a={a} (float), b={b} (int) -> resta={resta}, división={division:.2f}")
# Out:
# a=10.0 (float), b=7 (int) -> resta=3.0, división=1.43

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <span style="color:orange;">En este espacio se estan declarando variables de tipo string y lo que estamos haciendo es cambiando el tipo de variables de cada una a tipo int y float y con esos cambios ocupar las variables que cambiaste para poder realizar operaciones</span>

# %% [markdown]
# ### 4-.OPERADORES Y EXPRESIONES

# %% [markdown]
# ##### EJEMPLO

# %%
a, b = 7, 3
print("Suma:", a+b)
print("¿a es mayor que b?:", a > b)
print("¿a es mayor que 5 y b menor que 5?:", a > 5 and b < 5)
# Out:
# Suma: 10
# ¿a es mayor que b?: True
# ¿a es mayor que 5 y b menor que 5?: True

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <span style="color:pink;">Los operadores me permiten hacer cálculos o comparaciones. Hay aritméticos (+ - * / % // **), de comparación (== != > <) y lógicos (and, or, not). Con ellos construyo expresiones que Python evalúa paso a paso.</SPAN>

# %% [markdown]
# ### 5-. CADENAS (STRINGS)

# %% [markdown]
# ##### EJEMPLO

# %%
frase = "  Hola Python  "
print(frase.strip())         # Quita espacios
print(frase.upper())         # MAYÚSCULAS
print(frase.lower())         # minúsculas
print(frase.replace("Python", "Mundo"))
# Out:
# Hola Python
#   HOLA PYTHON
#   hola python
#   Hola Mundo

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <span style="color:BLUE;">Las cadenas (str) son textos que puedo manipular con métodos. Puedo convertir a mayúsculas, minúsculas, eliminar espacios, reemplazar palabras o dividirlas.Y en el ejemplo que realizamos se ve lo mismo y se convierten en cadenas tipo string</span>

# %% [markdown]
# ### 6-.Control de flujo (if, for, while)

# %% [markdown]
# ##### EJEMPLO

# %%
# if
edad = 18
if edad >= 18:
    print("Eres mayor de edad")

# for
for i in range(1, 6):
    print("Número:", i)

# while
contador = 3
while contador > 0:
    print("Cuenta regresiva:", contador)
    contador -= 1
# Out:
# Eres mayor de edad
# Número: 1
# Número: 2
# Número: 3
# Número: 4
# Número: 5
# Cuenta regresiva: 3
# Cuenta regresiva: 2
# Cuenta regresiva: 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <span style="color:orange;">El control de flujo en Python se refiere a las estructuras que permiten decidir el camino que seguirá un programa y la cantidad de veces que se repetirá una acción. Con estas estructuras se puede ejecutar un bloque de instrucciones si se cumple una condición, elegir entre varias alternativas o repetir operaciones. Por ejemplo, con una condición se puede tomar decisiones según el valor de una variable; con un ciclo definido como “for” se repite un bloque un número exacto de veces o se recorre una colección de datos; y con un ciclo condicional como “while” se ejecutan instrucciones mientras una condición sea verdadera. En resumen, el control de flujo da flexibilidad al programa para no ser rígido y lineal, sino que permite lógica y repetición controlada.</span>

# %% [markdown]
# ### 7-. COLECCIONES

# %% [markdown]
# ##### EJEMPLO

# %%
numeros = [1, 2, 3]
numeros.append(4)  # Agrego un elemento
print(numeros)     # [1, 2, 3, 4]
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <span style="color:brown;">Las colecciones son como cajas donde puedo guardar varios datos en un solo lugar. Por ejemplo, en vez de tener 10 variables para 10 números, mejor guardo esos números en una sola lista. Hay de diferentes tipos:
# Listas, que son cajas ordenadas y que puedo cambiar cuando quiera.
# Tuplas, que son como listas, pero no se pueden modificar.
# Conjuntos, que son cajas que no permiten elementos repetidos.
# Diccionarios, que son cajas donde cada dato tiene una “clave” para identificarlo.
# En resumen, las colecciones me ayudan a organizar muchos datos de una manera más sencilla.</SPAN>

# %% [markdown]
# ### 8-.Compresiones

# %% [markdown]
# ##### EJEMPLO

# %%
cuadrados = [x*x for x in range(1, 6)]
pares = [x for x in range(10) if x%2==0]
dicc = {x: x**2 for x in range(1, 6)}

print(cuadrados)  # [1, 4, 9, 16, 25]
print(pares)      # [0, 2, 4, 6, 8]
print(dicc)       # {1:1, 2:4, 3:9, 4:16, 5:25}
# Out:
# [1, 4, 9, 16, 25]
# [0, 2, 4, 6, 8]
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <span style="color:red;">Esto es como un atajo para crear listas o colecciones rápido y sin tener que escribir tanto. En lugar de usar un ciclo largo, con una sola línea puedo generar muchos valores. También puedo poner condiciones, como guardar solo los números pares. Es básicamente una forma más corta y limpia de escribir lo mismo que haría con ciclos.</span>

# %% [markdown]
# ### 9-. FUNCIONES

# %% [markdown]
# ##### EJEMPLO

# %%
def area_rectangulo(base, altura):
    return base * altura

print("Área:", area_rectangulo(5, 3))
# Out:
# Área: 15

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <span style="color:GREEN;">Las funciones son como pequeñas máquinas dentro de mi programa. Yo les doy una entrada, hacen un trabajo, y muchas veces me regresan un resultado. Sirven para no estar repitiendo el mismo código en todos lados. Por ejemplo, si quiero sumar dos números en diferentes partes del programa, en vez de escribir la suma varias veces, hago una función y la llamo cuando la necesite. Así el programa está más ordenado y es más fácil de entender.</SPAN>

# %% [markdown]
# ### 10-. MODULOS

# %% [markdown]
# ##### EJEMPLO

# %%
contenido = '''
def limpiar_texto(s: str) -> str:
    return s.strip().lower()

def contar_vocales(s: str) -> dict:
    s = s.lower()
    vocs = "aeiouáéíóú"
    return {v: s.count(v) for v in vocs if s.count(v) > 0}
'''.lstrip()

with open("utilidades.py", "w", encoding="utf-8") as f:
    f.write(contenido)

# Lo importamos y usamos
import utilidades as ut

frase = "  HOLA Mundo, Programación en PYTHON  "
print("Limpia:", ut.limpiar_texto(frase))
print("Vocales:", ut.contar_vocales(frase))
# Out:
# Limpia: hola mundo, programación en python
# Vocales: {'a': 3, 'e': 1, 'i': 1, 'o': 4, 'u': 1, 'ó': 1}

# %% [markdown]
# <span style="color:PURPLE;">Los módulos son como cajitas de herramientas que ya están hechas y que yo puedo usar en mis programas. Python trae muchos módulos listos para cosas comunes, como matemáticas o trabajar con fechas. También puedo crear mis propios módulos para organizar mi código y después usarlos en otros proyectos. Los módulos me evitan volver a escribir código que ya tengo listo.</SPAN>

# %% [markdown]
# ### 11-. MANEJO DE ARCHIVOS

# %% [markdown]
# ##### EJEMPLO

# %%
notas = [9.5, 8.0, 7.5, 10.0, 8.5]
with open("notas.txt", "w", encoding="utf-8") as f:
    for n in notas:
        f.write(f"{n}\n")

leidas = []
with open("notas.txt", "r", encoding="utf-8") as f:
    for linea in f:
        leidas.append(float(linea.strip()))

promedio = sum(leidas) / len(leidas)
print("Notas leídas:", leidas, " Promedio:", round(promedio, 2))

# Mini contador de palabras (simple)
texto = "¡Hola, hola! Esto es una prueba. Prueba simple; hola."
with open("texto.txt", "w", encoding="utf-8") as f:
    f.write(texto)

import re
with open("texto.txt", "r", encoding="utf-8") as f:
    contenido = f.read().lower()
    contenido = re.sub(r"[^a-záéíóúñü\s]", " ", contenido)  # quita signos
    palabras = [p for p in contenido.split() if p]

from collections import Counter
top5 = Counter(palabras).most_common(5)
print("Top 5 palabras:", top5)
# Out:
# Notas leídas: [9.5, 8.0, 7.5, 10.0, 8.5]  Promedio: 8.7
# Top 5 palabras: [('hola', 3), ('prueba', 2), ('esto', 1), ('es', 1), ('una', 1)]

# %% [markdown]
# <span style="color:orange;">Esto es cuando mi programa necesita guardar información en la computadora o leer algo que ya está guardado. Por ejemplo, si quiero que un programa guarde las notas de los alumnos, esas notas se escriben en un archivo y después las puedo volver a leer. También puedo crear nuevos archivos o modificar los que ya existen. En pocas palabras, es lo que me permite que los datos no se pierdan cuando el programa se cierra.</spam>

# %% [markdown]
# ### 12-. EXPECIONES

# %% [markdown]
# ##### EJEMPLO

# %%
def dividir_seguro(a, b):
    if b == 0:
        raise ValueError("No se puede dividir entre cero.")
    return a / b

# Ejemplos con manejo de excepciones
casos = [(10, 2), (5, 0), ("9", 3)]
for x, y in casos:
    try:
        resultado = dividir_seguro(x, y)
    except TypeError as e:
        print(f"TypeError con ({x}, {y}): {e}")
    except ValueError as e:
        print(f"ValueError con ({x}, {y}): {e}")
    else:
        print(f"{x} / {y} = {resultado}")
    finally:
        pass  # lugar para liberar recursos si fuera necesario
# Out:
# 10 / 2 = 5.0
# ValueError con (5, 0): No se puede dividir entre cero.
# TypeError con (9, 3): unsupported operand type(s) for /: 'str' and 'int'

# %% [markdown]
# <span style="color:PINK;">Aquí se trata de cómo manejar los errores que pasan en un programa. Muchas veces algo puede fallar, como dividir entre cero, abrir un archivo que no existe o escribir mal un dato. Si no hago nada, el programa se detiene de golpe. Pero con las excepciones, en lugar de que se cierre, puedo darle una respuesta, como mostrar un mensaje de error o seguir con otra parte del código. Esto hace que mi programa sea más seguro y no se caiga tan fácil.</SPAM>
